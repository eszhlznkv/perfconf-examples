# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN

# %%
# Загрузка данных из CSV файла
data = pd.read_csv('/Users/evgenii/Documents/GitHub/perfconf/perfcong-jmeter-examples/data_api/ar_api.jtl', low_memory=False)

# Преобразование времени в читаемый формат, если необходимо
data['timeStamp'] = pd.to_datetime(data['timeStamp'], unit='ms')

# Фильтрация по столбцу sampleLabel
sample_labels = data['label'].unique()

# %% [markdown]
# ## Диаграммы плотности

# %%
# Итерация по каждому уникальному sampleLabel
for label in sample_labels:
    subset = data[data['label'] == label]  # Фильтрация по метке

    # Построение диаграммы плотности
    plt.figure(figsize=(10, 6))
    sns.kdeplot(subset['elapsed'], fill=True)
    plt.title(f'Density Plot for {label}')
    plt.xlabel('Response Time (ms)')
    plt.ylabel('Density')
    plt.show()
# Out:
# /var/folders/38/_rx6rl813f70rlbmhn_dp4z00000gn/T/ipykernel_69683/67376536.py:7: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(subset['elapsed'], fill=True)

# %%
# Нормализация responseTime
scaler = StandardScaler()

# Применение нормализации для каждого sampleLabel
for label in sample_labels:
    subset = data[data['label'] == label]
    subset['responseTime_normalized'] = scaler.fit_transform(subset[['elapsed']])
    
    # Обновляем данные после нормализации
    data.loc[data['label'] == label, 'responseTime_normalized'] = subset['responseTime_normalized']
# Out:
# /var/folders/38/_rx6rl813f70rlbmhn_dp4z00000gn/T/ipykernel_69683/4262780729.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['responseTime_normalized'] = scaler.fit_transform(subset[['elapsed']])
# /var/folders/38/_rx6rl813f70rlbmhn_dp4z00000gn/T/ipykernel_69683/4262780729.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['responseTime_normalized'] = scaler.fit_transform(subset[['elapsed']])
# /var/folders/38/_rx6rl813f70rlbmhn_dp4z00000gn/T/ipykernel_69683/4262780729.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['responseTime_normalized'] = scaler.fit_transform(subset[['elapsed']])
# /var/folders/38/_rx6rl813f70rlbmhn_dp4z00000gn/T/ipykernel_69683/4262780729.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['responseTime_normalized'] = scaler.fit_transform(subset[['elapsed']])

# %%
data
# Out:
#                    timeStamp  elapsed                          label  \
# 0    2024-08-11 21:23:36.583      484  JSR223 Sampler - props remove
# 1    2024-08-11 21:23:37.229      106                       GET_main
# 2    2024-08-11 21:23:37.242       99                       GET_main
# 3    2024-08-11 21:23:37.252      107                       GET_main
# 4    2024-08-11 21:23:37.260      100                       GET_main
# ...                      ...      ...                            ...
# 2996 2024-08-11 21:23:43.977      304                     POST_order
# 2997 2024-08-11 21:23:43.988      299                     POST_order
# 2998 2024-08-11 21:23:44.000      301                     POST_order
# 2999 2024-08-11 21:23:44.043      303                     POST_order
# 3000 2024-08-11 21:23:44.045      307                     POST_order
#
#       responseCode responseMessage                     threadName dataType  \
# 0              200              OK         setUp Thread Group 1-1     text
# 1              200              OK    Thread Group - baseline 1-1     text
# 2              200              OK    Thread Group - baseline 1-2     text
# 3              200              OK    Thread Group - baseline 1-3     text
# 4              200              OK    Thread Group - baseline 1-4     text
# ...            ...             ...                            ...      ...
# 2996           200              OK   Thread Group - baseline 1-98     text
# 2997           200              OK   Thread Group - baseline 1-96     text
# 2998           200              OK   Thread Group - baseline 1-97     text
# 2999           200              OK  Thread Group - baseline 1-100     text
# 3000           200              OK   Thread Group - baseline 1-99     text
#
#       success  failureMessage  bytes  sentBytes  grpThreads  allThreads  URL  \
# 0        True             NaN      4          0           1           1  NaN
# 1        True             NaN    114          0          11          11  NaN
# 2        True             NaN    114          0          12          12  NaN
# 3        True             NaN    114          0          13          13  NaN
# 4        True             NaN    114          0          13          13  NaN
# ...       ...             ...    ...        ...         ...         ...  ...
# 2996     True             NaN    114          0           5           5  NaN
# 2997     True             NaN    114          0           4           4  NaN
# 2998     True             NaN    114          0           3           3  NaN
# 2999     True             NaN    114          0           2           2  NaN
# 3000     True             NaN    114          0           1           1  NaN
#
#       Latency  IdleTime  Connect  responseTime_normalized
# 0           0         0        0                 0.000000
# 1           3         0        2                 0.705530
# 2          23         0        1                -1.246529
# 3          22         0        1                 0.984395
# 4          20         0        5                -0.967663
# ...       ...       ...      ...                      ...
# 2996       20         0        3                 0.126399
# 2997       23         0        4                -1.262599
# 2998        2         0        2                -0.707000
# 2999       49         0        4                -0.151401
# 3000       23         0        2                 0.959797
#
# [3001 rows x 18 columns]

# %%
# Настройка параметров DBSCAN
eps = 0.5  # радиус окружности для определения плотности
min_samples = 5  # минимальное количество точек для формирования кластера

# Кластеризация данных для каждого sampleLabel
for label in sample_labels:
    subset = data[data['label'] == label]
    X = subset[['responseTime_normalized']].values
    
    # Применение DBSCAN
    db = DBSCAN(eps=eps, min_samples=min_samples)
    clusters = db.fit_predict(X)
    
    # Добавление кластерных меток к подмножеству данных
    subset['cluster'] = clusters
    
    # Обновление данных
    data.loc[data['label'] == label, 'cluster'] = subset['cluster']
    
    # Определение количества уникальных кластеров (исключая -1, который обозначает шум)
    n_clusters = len(set(clusters)) - (1 if -1 in clusters else 0)
    
    # Вывод информации в консоль
    print(f'Sample Label: {label}')
    print(f'Number of clusters found: {n_clusters}')
    print(f'Clusters: {np.unique(clusters)}')
    print()
# Out:
# Sample Label: JSR223 Sampler - props remove
# Number of clusters found: 0
# Clusters: [-1]
#
# Sample Label: GET_main
# Number of clusters found: 1
# Clusters: [-1  0]
#
# Sample Label: GET_card
# Number of clusters found: 1
# Clusters: [-1  0]
#
# Sample Label: POST_order
# Number of clusters found: 1
# Clusters: [-1  0]
# /var/folders/38/_rx6rl813f70rlbmhn_dp4z00000gn/T/ipykernel_69683/3928906740.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['cluster'] = clusters
# /var/folders/38/_rx6rl813f70rlbmhn_dp4z00000gn/T/ipykernel_69683/3928906740.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['cluster'] = clusters
# /var/folders/38/_rx6rl813f70rlbmhn_dp4z00000gn/T/ipykernel_69683/3928906740.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['cluster'] = clusters
# /var/folders/38/_rx6rl813f70rlbmhn_dp4z00000gn/T/ipykernel_69683/3928906740.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['cluster'] = clusters
