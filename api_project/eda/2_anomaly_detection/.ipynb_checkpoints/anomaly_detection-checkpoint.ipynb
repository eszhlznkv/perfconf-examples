# %% [markdown]
# # Поиск Аномалий

# %%
import pandas as pd
from adtk.data import validate_series
from adtk.visualization import plot
from adtk.detector import ThresholdAD, InterQuartileRangeAD, LevelShiftAD
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Загрузка данных из CSV файла
data = pd.read_csv('/Users/evgenii/Documents/GitHub/perfconf/perfcong-jmeter-examples/data_api/ar_api_power.jtl', low_memory=False, parse_dates=True)

# Преобразование времени в читаемый формат, если необходимо
data['timeStamp'] = pd.to_datetime(data['timeStamp'], unit='ms')

# Фильтрация по столбцу sampleLabel
sample_labels = data['label'].unique()

# Построим индекс по timeStamp 
data.set_index('timeStamp', inplace=True)

# %%
data
# Out:
#                          elapsed                          label  responseCode  \
# timeStamp
# 2024-08-11 21:33:27.916       12  JSR223 Sampler - props remove           200
# 2024-08-11 21:33:28.034       98                       GET_main           200
# 2024-08-11 21:33:28.033      210                       GET_card           200
# 2024-08-11 21:33:28.244      300                     POST_order           200
# 2024-08-11 21:33:28.244      103                       GET_main           200
# ...                          ...                            ...           ...
# 2024-08-11 21:37:53.307      294                       GET_card           200
# 2024-08-11 21:37:53.601      298                     POST_order           200
# 2024-08-11 21:37:53.601      105                       GET_main           200
# 2024-08-11 21:37:53.601      293                       GET_card           200
# 2024-08-11 21:37:53.894      295                     POST_order           200
#
#                         responseMessage                            threadName  \
# timeStamp
# 2024-08-11 21:33:27.916              OK                setUp Thread Group 1-1
# 2024-08-11 21:33:28.034              OK  Thread Group - power degradation 1-1
# 2024-08-11 21:33:28.033              OK  Thread Group - power degradation 1-1
# 2024-08-11 21:33:28.244              OK  Thread Group - power degradation 1-1
# 2024-08-11 21:33:28.244              OK  Thread Group - power degradation 1-1
# ...                                 ...                                   ...
# 2024-08-11 21:37:53.307              OK  Thread Group - power degradation 1-1
# 2024-08-11 21:37:53.601              OK  Thread Group - power degradation 1-1
# 2024-08-11 21:37:53.601              OK  Thread Group - power degradation 1-1
# 2024-08-11 21:37:53.601              OK  Thread Group - power degradation 1-1
# 2024-08-11 21:37:53.894              OK  Thread Group - power degradation 1-1
#
#                         dataType  success  failureMessage  bytes  sentBytes  \
# timeStamp
# 2024-08-11 21:33:27.916     text     True             NaN      0          0
# 2024-08-11 21:33:28.034     text     True             NaN    114          0
# 2024-08-11 21:33:28.033     text     True             NaN      0          0
# 2024-08-11 21:33:28.244     text     True             NaN    114          0
# 2024-08-11 21:33:28.244     text     True             NaN    114          0
# ...                          ...      ...             ...    ...        ...
# 2024-08-11 21:37:53.307     text     True             NaN      0          0
# 2024-08-11 21:37:53.601     text     True             NaN    114          0
# 2024-08-11 21:37:53.601     text     True             NaN    114          0
# 2024-08-11 21:37:53.601     text     True             NaN      0          0
# 2024-08-11 21:37:53.894     text     True             NaN    114          0
#
#                          grpThreads  allThreads  URL  Latency  IdleTime  \
# timeStamp
# 2024-08-11 21:33:27.916           1           1  NaN        0         0
# 2024-08-11 21:33:28.034           1           1  NaN        9         0
# 2024-08-11 21:33:28.033           1           1  NaN        0         0
# 2024-08-11 21:33:28.244           1           1  NaN        9         0
# 2024-08-11 21:33:28.244           1           1  NaN       15         0
# ...                             ...         ...  ...      ...       ...
# 2024-08-11 21:37:53.307           1           1  NaN        0         0
# 2024-08-11 21:37:53.601           1           1  NaN        5         0
# 2024-08-11 21:37:53.601           1           1  NaN       11         0
# 2024-08-11 21:37:53.601           1           1  NaN        0         0
# 2024-08-11 21:37:53.894           1           1  NaN       35         0
#
#                          Connect
# timeStamp
# 2024-08-11 21:33:27.916        0
# 2024-08-11 21:33:28.034        2
# 2024-08-11 21:33:28.033        0
# 2024-08-11 21:33:28.244        2
# 2024-08-11 21:33:28.244        2
# ...                          ...
# 2024-08-11 21:37:53.307        0
# 2024-08-11 21:37:53.601        5
# 2024-08-11 21:37:53.601        3
# 2024-08-11 21:37:53.601        0
# 2024-08-11 21:37:53.894        3
#
# [3001 rows x 16 columns]

# %%
# ThresholdAD

for label in sample_labels:
    subset = data[data['label'] == label]
    subset = subset[['elapsed']]
    s = validate_series(subset)
        
    # Пороговый детектор
    threshold_ad = ThresholdAD(high=250, low=50)
    anomalies_threshold = threshold_ad.detect(s)
    count_threshold = int(anomalies_threshold.sum())
    
    # Визуализация результатов
    #plot(s, anomaly=anomalies_threshold, anomaly_color='red')
    
    # Вывод количества аномалий и сообщения об ошибке
    anomaly_threshold = 10  # Заданный порог количества аномалий
    plot(s, anomaly=anomalies_threshold, ts_linewidth=1, ts_markersize=3, anomaly_markersize=5, anomaly_color='red', anomaly_tag="marker", legend=label);
    
    print(f"Количество аномалий (ThresholdAD) в {label}:", count_threshold)
    if count_threshold > anomaly_threshold:
        print("Error: ThresholdAD выявил слишком много аномалий")
# Out:
# Количество аномалий (ThresholdAD) в JSR223 Sampler - props remove: 1
# Количество аномалий (ThresholdAD) в GET_main: 0
# Количество аномалий (ThresholdAD) в GET_card: 702
# Error: ThresholdAD выявил слишком много аномалий
# Количество аномалий (ThresholdAD) в POST_order: 1000
# Error: ThresholdAD выявил слишком много аномалий

# %% [markdown]
# # InterQuartileRangeAD

# %%
# InterQuartileRangeAD

for label in sample_labels:
    subset = data[data['label'] == label]
    subset = subset[['elapsed']]
    s = validate_series(subset)

    iqr_ad = InterQuartileRangeAD(c=0.3)
    anomalies = iqr_ad.fit_detect(s)
    count_threshold = int(anomalies.sum())
    
    # Вывод количества аномалий и сообщения об ошибке
    anomaly_threshold = 10  # Заданный порог количества аномалий
    plot(s, anomaly=anomalies, ts_linewidth=1, ts_markersize=3, anomaly_markersize=5, anomaly_color='red', anomaly_tag="marker", legend=label);
    
    print(f"Количество аномалий (InterQuartileRangeAD) в {label}:", count_threshold)
    if count_threshold > anomaly_threshold:
        print("Error: InterQuartileRangeAD выявил слишком много аномалий")
# Out:
# Количество аномалий (InterQuartileRangeAD) в JSR223 Sampler - props remove: 0
# Количество аномалий (InterQuartileRangeAD) в GET_main: 185
# Error: InterQuartileRangeAD выявил слишком много аномалий
# Количество аномалий (InterQuartileRangeAD) в GET_card: 10
# Количество аномалий (InterQuartileRangeAD) в POST_order: 169
# Error: InterQuartileRangeAD выявил слишком много аномалий

# %% [markdown]
# # LevelShiftAD

# %%
# LevelShiftAD

for label in sample_labels:
    subset = data[data['label'] == label]
    subset = subset[['elapsed']]
    s = validate_series(subset)

    level_shift_ad = LevelShiftAD(c=6.0, side='both', window=12)
    anomalies = level_shift_ad.fit_detect(s)
    count_threshold = int(anomalies.sum())
    
    # Вывод количества аномалий и сообщения об ошибке
    anomaly_threshold = 10  # Заданный порог количества аномалий
    plot(s, anomaly=anomalies, anomaly_color='red')
    # plot(s, anomaly=anomalies, ts_linewidth=1, ts_markersize=3, anomaly_markersize=5, anomaly_color='red', anomaly_tag="marker", legend=label);
    
    print(f"Количество аномалий (InterQuartileRangeAD) в {label}:", count_threshold)
    if count_threshold > anomaly_threshold:
        print("Error: LevelShiftAD выявил слишком много аномалий")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[25], line 9
#       6 s = validate_series(subset)
#       8 level_shift_ad = LevelShiftAD(c=6.0, side='both', window=12)
# ----> 9 anomalies = level_shift_ad.fit_detect(s)
#      10 count_threshold = int(anomalies.sum())
#      12 # Вывод количества аномалий и сообщения об ошибке
#
# File ~/Documents/GitHub/perfconf/perfcong-jmeter-examples/api_project/eda/env/lib/python3.12/site-packages/adtk/_detector_base.py:247, in _TrainableUnivariateDetector.fit_predict(self, ts, return_list)
#     205 def fit_predict(
#     206     self, ts: Union[pd.Series, pd.DataFrame], return_list: bool = False
#     207 ) -> Union[
#    (...)
#     213     ],
#     214 ]:
#     215     """Train the detector and detect anomalies from the time series used
#     216     for training.
#     217
#    (...)
#     245
#     246     """
# --> 247     self.fit(ts)
#     248     return self.detect(ts, return_list=return_list)
#
# File ~/Documents/GitHub/perfconf/perfcong-jmeter-examples/api_project/eda/env/lib/python3.12/site-packages/adtk/_detector_base.py:152, in _TrainableUnivariateDetector.fit(self, ts)
#     141 def fit(self, ts: Union[pd.Series, pd.DataFrame]) -> None:
#     142     """Train the detector with given time series.
#     143
#     144     Parameters
#    (...)
#     150
#     151     """
# --> 152     self._fit(ts)
#
# File ~/Documents/GitHub/perfconf/perfcong-jmeter-examples/api_project/eda/env/lib/python3.12/site-packages/adtk/_base.py:174, in _TrainableUnivariateModel._fit(self, ts)
#     172     # fit model for each column
#     173     for col in df.columns:
# --> 174         self._models[col].fit(df[col])
#     175     self._fitted = 2
#     176 else:
#
# File ~/Documents/GitHub/perfconf/perfcong-jmeter-examples/api_project/eda/env/lib/python3.12/site-packages/adtk/_detector_base.py:152, in _TrainableUnivariateDetector.fit(self, ts)
#     141 def fit(self, ts: Union[pd.Series, pd.DataFrame]) -> None:
#     142     """Train the detector with given time series.
#     143
#     144     Parameters
#    (...)
#     150
#     151     """
# --> 152     self._fit(ts)
#
# File ~/Documents/GitHub/perfconf/perfcong-jmeter-examples/api_project/eda/env/lib/python3.12/site-packages/adtk/_base.py:154, in _TrainableUnivariateModel._fit(self, ts)
#     152 if isinstance(ts, pd.Series):
#     153     s = ts.copy()  # type: pd.Series
# --> 154     self._fit_core(s)
#     155     self._fitted = 1
#     156 elif isinstance(ts, pd.DataFrame):
#
# File ~/Documents/GitHub/perfconf/perfcong-jmeter-examples/api_project/eda/env/lib/python3.12/site-packages/adtk/detector/_detector_1d.py:688, in LevelShiftAD._fit_core(self, s)
#     686 def _fit_core(self, s: pd.Series) -> None:
#     687     self._sync_params()
# --> 688     self.pipe_.fit(s)
#
# File ~/Documents/GitHub/perfconf/perfcong-jmeter-examples/api_project/eda/env/lib/python3.12/site-packages/adtk/pipe/_pipe.py:888, in Pipenet.fit(self, ts, skip_fit, return_intermediate)
#     886 input = self._get_input(step, results)
#     887 if need_fit[step_name] and (not need_predict[step_name]):
# --> 888     step["model"].fit(input)
#     889     results.update({step_name: None})
#     890 elif (not need_fit[step_name]) and need_predict[step_name]:
#
# File ~/Documents/GitHub/perfconf/perfcong-jmeter-examples/api_project/eda/env/lib/python3.12/site-packages/adtk/_detector_base.py:152, in _TrainableUnivariateDetector.fit(self, ts)
#     141 def fit(self, ts: Union[pd.Series, pd.DataFrame]) -> None:
#     142     """Train the detector with given time series.
#     143
#     144     Parameters
#    (...)
#     150
#     151     """
# --> 152     self._fit(ts)
#
# File ~/Documents/GitHub/perfconf/perfcong-jmeter-examples/api_project/eda/env/lib/python3.12/site-packages/adtk/_base.py:154, in _TrainableUnivariateModel._fit(self, ts)
#     152 if isinstance(ts, pd.Series):
#     153     s = ts.copy()  # type: pd.Series
# --> 154     self._fit_core(s)
#     155     self._fitted = 1
#     156 elif isinstance(ts, pd.DataFrame):
#
# File ~/Documents/GitHub/perfconf/perfcong-jmeter-examples/api_project/eda/env/lib/python3.12/site-packages/adtk/detector/_detector_1d.py:242, in InterQuartileRangeAD._fit_core(self, s)
#     240 def _fit_core(self, s: pd.Series) -> None:
#     241     if s.count() == 0:
# --> 242         raise RuntimeError("Valid values are not enough for training.")
#     243     q1 = s.quantile(0.25)
#     244     q3 = s.quantile(0.75)
#
# RuntimeError: Valid values are not enough for training.
